# %%
pip install faker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faker in /home/anacleto/.local/lib/python3.10/site-packages (18.5.1)
# Requirement already satisfied: python-dateutil>=2.4 in /home/anacleto/.local/lib/python3.10/site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from collections import defaultdict
import pandas as pd
import random
import numpy as np
from faker import Faker

# %%
# Cria uma instância do Faker
faker = Faker()

# Gera 50 nomes sem repeticao usando o faker
nomes = np.array([])
while len(nomes) < 50:
    nome = faker.name()
    if nome not in nomes:
        nomes = np.append(nomes, nome)
# Out:
# /tmp/ipykernel_24258/411245105.py:8: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if nome not in nomes:

# %%
estilos_musica = ["Rock", "Pop", "Funk", "Hip Hop", "Sertanejo", "Eletrônica", "MPB", "Reggae", "Jazz", "Clássica"]

tabela = []

for i in range(50):
    nome = nomes[i]
    id_usuario = i + 1
    estilo = random.choice(estilos_musica)
    tabela.append([nome, id_usuario, estilo])

usuarios = pd.DataFrame(tabela,columns=['Nome','id usuario','estilo'])
usuarios
# Out:
#                      Nome  id usuario      estilo
# 0          Catherine Cook           1    Clássica
# 1            Jill Francis           2   Sertanejo
# 2   Ms. Kimberly Richards           3      Reggae
# 3              Edwin Hunt           4         Pop
# 4           Justin Oliver           5     Hip Hop
# 5          Angela Hampton           6      Reggae
# 6             Scott Meyer           7        Rock
# 7         Nathaniel Keith           8  Eletrônica
# 8        Russell Morrison           9        Rock
# 9             Angela Kane          10      Reggae
# 10      Stephanie Collins          11        Jazz
# 11       Gregory Thompson          12     Hip Hop
# 12           Vickie Black          13        Rock
# 13            Angela Reed          14     Hip Hop
# 14          Dylan Stewart          15    Clássica
# 15            Maria Jones          16         MPB
# 16      Jessica Davenport          17    Clássica
# 17          Jeremy Warner          18        Funk
# 18            Cindy Lewis          19        Jazz
# 19           Timothy Cook          20    Clássica
# 20          Jennifer Odom          21  Eletrônica
# 21       Christine Bailey          22   Sertanejo
# 22    Patricia Montgomery          23        Jazz
# 23         Hannah Aguilar          24    Clássica
# 24         Mark Valentine          25        Funk
# 25         Terry Williams          26        Funk
# 26      Jennifer Gonzales          27  Eletrônica
# 27          Barbara Jones          28         MPB
# 28       Heather Anderson          29   Sertanejo
# 29            Adam Vaughn          30     Hip Hop
# 30       Dr. Judy Miranda          31         MPB
# 31          Shannon Perry          32        Jazz
# 32          Hannah Taylor          33        Jazz
# 33           Robert Brown          34     Hip Hop
# 34           Brian Holmes          35         Pop
# 35         Angelica White          36      Reggae
# 36          Maureen Smith          37      Reggae
# 37          Mary Sullivan          38        Jazz
# 38        Christina Smith          39         Pop
# 39     Mrs. Heidi Johnson          40        Funk
# 40        Jennifer Hughes          41         Pop
# 41          Rhonda Chavez          42        Funk
# 42         Carolyn Peters          43         Pop
# 43           Zachary Wade          44  Eletrônica
# 44           Alice Murray          45  Eletrônica
# 45         Carmen Robbins          46        Jazz
# 46           Rebecca King          47      Reggae
# 47           Jared Nelson          48    Clássica
# 48          Mitchell Dunn          49     Hip Hop
# 49           Amanda Lopez          50    Clássica

# %%
class Grafo(object):

    def __init__(self, arestas, direcionado=False):
        #inicializa os atributos do grafo
        self.adj = defaultdict(set)
        self.direcionado = direcionado
        self.adiciona_arestas(arestas)

    #obtem a lista de vertices do grafo
    def get_vertices(self):
        
        return list(self.adj.keys())

    #obtem a lista de arestas do grafo
    def get_arestas(self):
        
        return [(k, v) for k in self.adj.keys() for v in self.adj[k]]

    #Adciona as arestas no grafo
    def adiciona_arestas(self, arestas):
        
        for u, v in arestas:
            self.adiciona_arco(u, v)

    #adciona um arco entre u e v
    def adiciona_arco(self, u, v):
        
        self.adj[u].add(v)
        # Se o grafo é não-direcionado, precisamos adicionar arcos nos dois sentidos.
        if not self.direcionado:
            self.adj[v].add(u)

    #verifica a existencia de arestas
    def existe_aresta(self, u, v):
        return u in self.adj and v in self.adj[u]


    def __len__(self):
        return len(self.adj)


    def __str__(self):
        return '{}({})'.format(self.__class__.__name__, dict(self.adj))


    def __getitem__(self, v):
        return self.adj[v]

# %%
# Cria a lista de arestas.
arestas = [('Rock', 'Led Zeppelin'), ('Rock', 'The Rolling Stones'), ('Rock', 'Queen'), ('Pop', 'Michael Jackson'), ('Pop', 'Madonna'),('Pop', 'Michael Jackson'), ('Pop', 'Beyoncé'),('Hip Hop', 'Notorious B.I.G.'), ('Hip Hop', 'Tupac Shakur'), ('Hip Hop', 'Jay-z'),('Country', 'Johnny Cash'), ('Country', 'Dolly Parton'),('Country','Kenny Rogers')]


# Cria e imprime o grafo.
grafo = Grafo(arestas, direcionado=True)

grafo.get_arestas()

grafo.adiciona_arestas([('Reagge','Bob Marley')])

grafo.existe_aresta('Reagge','Bob Marley')

grafo.get_vertices()

grafo.__str__()
# Out:
# "Grafo({'Rock': {'The Rolling Stones', 'Led Zeppelin', 'Queen'}, 'Pop': {'Beyoncé', 'Michael Jackson', 'Madonna'}, 'Hip Hop': {'Tupac Shakur', 'Notorious B.I.G.', 'Jay-z'}, 'Country': {'Johnny Cash', 'Kenny Rogers', 'Dolly Parton'}, 'Reagge': {'Bob Marley'}})"
