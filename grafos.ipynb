# %%
pip install faker
# Out:
# Requirement already satisfied: faker in c:\users\bruno\appdata\local\programs\python\python38\lib\site-packages (18.5.1)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\bruno\appdata\local\programs\python\python38\lib\site-packages (from faker) (2.8.1)
# Requirement already satisfied: six>=1.5 in c:\users\bruno\appdata\local\programs\python\python38\lib\site-packages (from python-dateutil>=2.4->faker) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip available: 22.3.1 -> 23.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from collections import defaultdict
import pandas as pd
import random
import numpy as np
from faker import Faker

# %%
# Cria uma instância do Faker
faker = Faker()

# Gera 50 nomes sem repeticao usando o faker
nomes = np.array([])
while len(nomes) < 50:
    nome = faker.name()
    if nome not in nomes:
        nomes = np.append(nomes, nome)
# Out:
# <ipython-input-8-8400ba16db55>:8: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if nome not in nomes:

# %%
estilos_musica = ["Rock", "Pop", "Funk", "Hip Hop", "Sertanejo", "Eletrônica", "MPB", "Reggae", "Jazz", "Clássica"]

tabela = []

for i in range(50):
    nome = nomes[i]
    id_usuario = i + 1
    estilo = random.choice(estilos_musica)
    tabela.append([nome, id_usuario, estilo])

usuarios = pd.DataFrame(tabela,columns=['Nome','id usuario','estilo'])
usuarios
# Out:
#                    Nome  id usuario      estilo
# 0         Patrick Cantu           1    Clássica
# 1        Mary Hernandez           2        Funk
# 2      Kimberly Mercado           3    Clássica
# 3      Kimberly Rosales           4         MPB
# 4         Clinton Lopez           5   Sertanejo
# 5       Christine Davis           6    Clássica
# 6            Todd White           7        Jazz
# 7        Ashley Stewart           8        Jazz
# 8         Lisa Gonzalez           9     Hip Hop
# 9          Joseph Clark          10   Sertanejo
# 10          Ashley Frey          11    Clássica
# 11        Roberta Young          12        Jazz
# 12      James Hernandez          13    Clássica
# 13  Mr. Gabriel Simmons          14  Eletrônica
# 14     Cameron Schwartz          15        Funk
# 15       Brittney Hicks          16        Rock
# 16        Megan Buckley          17      Reggae
# 17          Edwin Cohen          18     Hip Hop
# 18         Henry Kelley          19      Reggae
# 19         Monica Davis          20   Sertanejo
# 20         Scott Fields          21      Reggae
# 21         Justin White          22        Rock
# 22       Kimberly Smith          23  Eletrônica
# 23       Donna Ellis MD          24        Rock
# 24            Tammy Fox          25        Funk
# 25      Kenneth Johnson          26  Eletrônica
# 26         Hector White          27        Funk
# 27       Daniel Johnson          28    Clássica
# 28         Brad Johnson          29   Sertanejo
# 29      Julie Smith DDS          30         Pop
# 30     Laura Flores DDS          31        Funk
# 31          Larry Brown          32         Pop
# 32        Darren Barnes          33        Rock
# 33       Rachael Morton          34        Rock
# 34      Patrick Schmidt          35        Jazz
# 35       Patricia Green          36        Rock
# 36        Jessica Kelly          37        Jazz
# 37       Caitlin Walton          38     Hip Hop
# 38    Jennifer Williams          39        Rock
# 39         Traci Miller          40    Clássica
# 40     Alyssa Wilkerson          41  Eletrônica
# 41        Dorothy Ortiz          42         MPB
# 42          Joshua Wolf          43         MPB
# 43       Tammy Thornton          44    Clássica
# 44         Jessica King          45     Hip Hop
# 45      Katherine Baker          46    Clássica
# 46         Carol Lawson          47   Sertanejo
# 47        Zachary Johns          48    Clássica
# 48   Michael Montgomery          49   Sertanejo
# 49         Daniel Rocha          50         Pop

# %%
class Grafo(object):

    def __init__(self, arestas, direcionado=False):
        tamanho=0
        #inicializa os atributos do grafo
        self.adj = defaultdict(set)
        self.direcionado = direcionado
        self.tamanho = tamanho
        self.adiciona_arestas(arestas)

    #obtem a lista de vertices do grafo
    def get_vertices(self):
        
        return list(self.adj.keys())

    #obtem a lista de arestas do grafo
    def get_arestas(self):
        
        return [(k, v) for k in self.adj.keys() for v in self.adj[k]]

    #Adciona as arestas no grafo
    def adiciona_arestas(self, arestas):
        
        for u, v in arestas:
            self.tamanho += 1
            self.adiciona_arco(u, v)

    #adciona um arco entre u e v
    def adiciona_arco(self, u, v):
        
        self.adj[u].add(v)
        # Se o grafo é não-direcionado, precisamos adicionar arcos nos dois sentidos.
        if not self.direcionado:
            self.adj[v].add(u)

    #verifica a existencia de arestas
    def existe_aresta(self, u, v):
        return u in self.adj and v in self.adj[u]

    def verifica_tamanho(self):
        return self.tamanho

    def __len__(self):
        return len(self.adj)


    def __str__(self):
        return '{}({})'.format(self.__class__.__name__, dict(self.adj))


    def __getitem__(self, v):
        return self.adj[v]

# %%
# Cria a lista de arestas.
arestas = [('Rock', 'Led Zeppelin'), ('Rock', 'The Rolling Stones'), ('Rock', 'Queen'), ('Pop', 'Michael Jackson'), ('Pop', 'Madonna'),('Pop', 'Michael Jackson'), ('Pop', 'Beyoncé'),('Hip Hop', 'Notorious B.I.G.'), ('Hip Hop', 'Tupac Shakur'), ('Hip Hop', 'Jay-z'),('Country', 'Johnny Cash'), ('Country', 'Dolly Parton'),('Country','Kenny Rogers')]


# Cria e imprime o grafo.
grafo = Grafo(arestas, direcionado=False)

grafo.get_arestas()

grafo.adiciona_arestas([('Reagge','Bob Marley')])

grafo.existe_aresta('Reagge','Bob Marley')

grafo.get_vertices()

print(grafo.tamanho)

grafo.__str__()

h = list(grafo.adj.keys())

h[1]
# Out:
# 14
# 'Led Zeppelin'

# %%
def hash_string(palavra):
    a = np.fromstring(palavra, dtype=np.uint8)
    soma = 0
    for i in a:
        soma += i
    return soma

# %%
def verifica_dict(visitado:dict, chave:int, nome:str):
    for i in visitado[str(chave)]:
        if i == nome:
            return True
        
    return False

# %%
def bfs(G, inicio: str):

    visitado = {}

    IF = 0
    FF = 0

    fila = []
    ret = []
    fila.append(inicio)

    chave = hash_string(inicio)

    visitado[str(chave)] = []
    visitado[str(chave)].append(inicio)

    FF+=1

    while fila:
        IF = (IF + 1) % G.tamanho
        pr = fila.pop(0)
        ret.append(pr)

        for j in list(G.adj.keys()):
            cha = hash_string(j)
            if str(cha) not in visitado:
                visitado[str(cha)] = []
                visitado[str(cha)].append(j)
                fila.append(j)


            elif verifica_dict(visitado=visitado, chave=cha, nome=j) != True:    
                visitado[cha].append(j)
                fila.append(j)

    return ret

# %%
li = bfs(grafo, inicio="Queen")
print(li)
# Out:
# ['Queen', 'Rock', 'Led Zeppelin', 'The Rolling Stones', 'Pop', 'Michael Jackson', 'Madonna', 'Beyoncé', 'Hip Hop', 'Notorious B.I.G.', 'Tupac Shakur', 'Jay-z', 'Country', 'Johnny Cash', 'Dolly Parton', 'Kenny Rogers', 'Reagge', 'Bob Marley']
# <ipython-input-13-d176b196d2f8>:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   a = np.fromstring(palavra, dtype=np.uint8)
