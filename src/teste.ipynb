# %%
import pandas as pd
from collections import defaultdict
import random
import numpy as np
from faker import Faker

usuarios = pd.read_csv("usuarios.csv")
df = pd.DataFrame(usuarios)

arestas = []
cont = 0

for i, j in zip(df["estilo"], df["artista favorito"]):
    print(i + " i")
    print(j + " j")
    cont+=1


print(arestas)
# Out:
# Rock i
# R.E.M. j
# Rock i
# Black Sabbath j
# Sertanejo i
# Henrique & Juliano j
# Eletrônica i
# Hardwell j
# Hip Hop i
# Tyler, The Creator j
# Rock i
# Green Day j
# Hip Hop i
# Drake j
# Eletrônica i
# Tiesto j
# Hip Hop i
# Rakim j
# Rock i
# The Rolling Stones j
# Sertanejo i
# Loubet j
# Rock i
# Muse j
# Sertanejo i
# Rick & Renner j
# Pop i
# Lizzo j
# Pop i
# The Weeknd j
# Pop i
# Justin Bieber j
# Rock i
# Radiohead j
# Pop i
# Dua Lipa j
# Hip Hop i
# Notorious B.I.G. j
# Rock i
# System of a Down j
# Sertanejo i
# Eduardo Costa j
# Hip Hop i
# Logic j
# Eletrônica i
# Diplo j
# Eletrônica i
# Nervo j
# Rock i
# Arctic Monkeys j
# Pop i
# Jessie J j
# Rock i
# Red Hot Chili Peppers j
# Rock i
# Arctic Monkeys j
# Rock i
# Queen j
# Eletrônica i
# Eric Prydz j
# Hip Hop i
# Notorious B.I.G. j
# Hip Hop i
# J. Cole j
# Hip Hop i
# Wu-Tang Clan j
# Sertanejo i
# Henrique & Juliano j
# Pop i
# Sam Smith j
# Eletrônica i
# Armin van Buuren j
# Rock i
# The Rolling Stones j
# Eletrônica i
# Above & Beyond j
# Eletrônica i
# R3hab j
# Pop i
# Jessie J j
# Rock i
# Muse j
# Eletrônica i
# Armin van Buuren j
# Sertanejo i
# César Menotti & Fabiano j
# Pop i
# Lady Gaga j
# Hip Hop i
# Lil Kim j
# Pop i
# Jason Derulo j
# Rock i
# Muse j
# Rock i
# Black Sabbath j
# Rock i
# The Beatles j
# Hip Hop i
# Lil Wayne j
# []

# %%
class Grafo(object):

    def __init__(self, arestas, direcionado=False):
        tamanho=0
        #inicializa os atributos do grafo
        self.adj = defaultdict(set)
        self.direcionado = direcionado
        self.tamanho = tamanho
        self.adiciona_arestas(arestas)
        self.conecta_subgeneros(arestas)

    #obtem a lista de vertices do grafo
    def get_vertices(self):
        
        return list(self.adj.keys())

    #obtem a lista de arestas do grafo
    def get_arestas(self):
        
        return [(k, v) for k in self.adj.keys() for v in self.adj[k]]

    #Adciona as arestas no grafo
    def adiciona_arestas(self, arestas):
        
        for i, j in zip(arestas["sub_genero"], arestas["artista favorito"]):
            self.tamanho += 1
            self.adiciona_arco(i, j)

    def adiciona_estilos(self, arestas):
        
        for u, v in arestas:
            self.tamanho += 1
            self.direcionado = True
            self.adiciona_arco(u, v)

    def conecta_subgeneros(self, arestas):
        
        for i, j in zip(arestas["estilo"], arestas["sub_genero"]):
            self.tamanho += 1
            self.adiciona_arco(i, j)

    #adciona um arco entre u e v
    def adiciona_arco(self, u, v):
        
        self.adj[u].add(v)
        # Se o grafo é não-direcionado, precisamos adicionar arcos nos dois sentidos.
        if not self.direcionado:
            self.adj[v].add(u)

    #verifica a existencia de arestas
    def existe_aresta(self, u, v):
        return u in self.adj and v in self.adj[u]

    def verifica_tamanho(self):
        return self.tamanho

    def __len__(self):
        return len(self.adj)


    def __str__(self):
        return '{}({})'.format(self.__class__.__name__, dict(self.adj))


    def __getitem__(self, v):
        return self.adj[v]

# %%
grafo = Grafo(df, direcionado=False)

for i in df["estilo"]:
    grafo.adiciona_estilos([('Estilos', str(i))])

print(grafo.get_vertices())
# Out:
# ['Punk', 'R.E.M.', 'Progressivo', 'Black Sabbath', 'Música Raiz', 'Henrique & Juliano', 'Trance', 'Hardwell', 'Rap', 'Tyler, The Creator', 'Green Day', 'Old School', 'Drake', 'Dubstep', 'Tiesto', 'Gangsta', 'Rakim', 'Indie', 'The Rolling Stones', 'Folk', 'Loubet', 'Muse', 'Rick & Renner', 'Bubblegum pop', 'Lizzo', 'R&B', 'The Weeknd', 'Justin Bieber', 'Clássico', 'Radiohead', 'Dua Lipa', 'Boom Bap', 'Notorious B.I.G.', 'System of a Down', 'Modão', 'Eduardo Costa', 'Logic', 'Techno', 'Diplo', 'Nervo', 'Metal', 'Arctic Monkeys', 'Indie pop', 'Jessie J', 'Red Hot Chili Peppers', 'Queen', 'Drum and Bass', 'Eric Prydz', 'Trap', 'J. Cole', 'Wu-Tang Clan', 'Electropop', 'Sam Smith', 'Chillout    ', 'Armin van Buuren', 'House', 'Above & Beyond', 'R3hab', nan, 'César Menotti & Fabiano', 'Dance', 'Lady Gaga', 'Lil Kim', 'Jason Derulo', 'The Beatles', 'Lil Wayne', 'Rock', 'Sertanejo', 'Eletrônica', 'Hip Hop', 'Pop', 'Estilos']

# %%
def hash_string(palavra):
    soma = hash(palavra)
    return soma

def verifica_dict(visitado:dict, chave:int, nome:str):
    for i in visitado[str(chave)]:
        if i == nome:
            return True
        
    return False

def bfs(G, inicio: str):

    visitado = {}

    fila = []
    ret = []
    fila.append(inicio)

    chave = hash_string(inicio)

    visitado[str(chave)] = []
    visitado[str(chave)].append(inicio)

    count = 0   #usado para acessar estilo


    while fila:
        pr = fila.pop(0)
        ret.append(pr)
        l = list(G["Estilos"])

        for j in list(G[pr]):
            cha = hash_string(j)
            if str(cha) not in visitado:
                visitado[str(cha)] = []
                visitado[str(cha)].append(j)
                fila.append(j)


            elif verifica_dict(visitado=visitado, chave=cha, nome=j) != True:    
                visitado[str(cha)].append(j)
                fila.append(j)

        if fila == []:
            if count<len(l):
                fila.append(l[count])
                count+=1
    return ret

# %%
li = bfs(grafo, inicio="Green Day")
print(li)
# Out:
# ['Green Day', 'Progressivo', 'Red Hot Chili Peppers', 'Rock', 'Black Sabbath', 'Punk', 'Indie', 'Clássico', 'Metal', 'Queen', 'R.E.M.', 'The Rolling Stones', 'Muse', 'Radiohead', 'System of a Down', 'The Beatles', 'Arctic Monkeys', 'Pop', 'Bubblegum pop', 'Electropop', 'Dance', 'Indie pop', 'R&B', 'Pop', 'Lizzo', 'Dua Lipa', 'Jason Derulo', 'Sam Smith', 'Lady Gaga', 'Jessie J', 'The Weeknd', 'Justin Bieber', 'Sertanejo', nan, 'Modão', 'Música Raiz', 'Folk', 'César Menotti & Fabiano', 'Sertanejo', 'Eduardo Costa', 'Henrique & Juliano', 'Rick & Renner', 'Loubet', nan, nan, 'Eletrônica', 'Chillout    ', 'Trance', 'Dubstep', 'House', 'Drum and Bass', 'Techno', 'Armin van Buuren', 'Eletrônica', 'Hardwell', 'Nervo', 'Tiesto', 'R3hab', 'Above & Beyond', 'Eric Prydz', 'Diplo', 'Hip Hop', 'Gangsta', 'Trap', 'Boom Bap', 'Rap', 'Old School', 'Hip Hop', 'Rakim', 'J. Cole', 'Lil Wayne', 'Logic', 'Notorious B.I.G.', 'Tyler, The Creator', 'Lil Kim', 'Wu-Tang Clan', 'Drake', 'Rock']
