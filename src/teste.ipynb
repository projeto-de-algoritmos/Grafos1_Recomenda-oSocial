# %%
import pandas as pd
from collections import defaultdict
import random
import numpy as np
from faker import Faker

usuarios = pd.read_csv("usuarios.csv")
df = pd.DataFrame(usuarios)

arestas = []
cont = 0

for i, j in zip(df["estilo"], df["artista favorito"]):
    print(i + " i")
    print(j + " j")
    cont+=1


print(arestas)
# Out:
# Pop i
# Charlie Puth j
# Rock i
# Bon Jovi j
# Eletrônica i
# Martin Garrix j
# Hip Hop i
# J. Cole j
# Rock i
# AC/DC j
# Sertanejo i
# Loubet j
# Pop i
# Lauv j
# Rock i
# Coldplay j
# Sertanejo i
# Matheus & Kauan j
# Pop i
# Niall Horan j
# Rock i
# Pink Floyd j
# Hip Hop i
# Outkast j
# Sertanejo i
# Paula Fernandes j
# Rock i
# Metallica j
# Rock i
# Linkin Park j
# Hip Hop i
# Kendrick Lamar j
# Sertanejo i
# Gian & Giovani j
# Rock i
# Pink Floyd j
# Hip Hop i
# Lauryn Hill j
# Sertanejo i
# Zezé di Camargo j
# Sertanejo i
# Daniel j
# Sertanejo i
# Zé Neto & Cristiano j
# Eletrônica i
# R3hab j
# Rock i
# System of a Down j
# Rock i
# Guns N' Roses j
# Hip Hop i
# Kanye West j
# Rock i
# Green Day j
# Eletrônica i
# Marshmello j
# Eletrônica i
# David Guetta j
# Hip Hop i
# Big Daddy Kane j
# Eletrônica i
# Major Lazer j
# Eletrônica i
# Martin Garrix j
# Eletrônica i
# Axwell j
# Hip Hop i
# MF DOOM j
# Pop i
# Jessie J j
# Rock i
# The Beatles j
# Sertanejo i
# Guilherme & Santiago j
# Sertanejo i
# Henrique & Juliano j
# Sertanejo i
# Zé Neto & Cristiano j
# Rock i
# Guns N' Roses j
# Rock i
# The Doors j
# Hip Hop i
# A$AP Rocky j
# Hip Hop i
# Jay-Z j
# Rock i
# Oasis j
# Sertanejo i
# Gino & Geno j
# Pop i
# Camila Cabello j
# Eletrônica i
# Axwell j
# Eletrônica i
# The Chainsmokers j
# Sertanejo i
# Cristiano Araújo j
# Sertanejo i
# Munhoz & Mariano j
# []

# %%
class Grafo(object):

    def __init__(self, arestas, direcionado=False):
        tamanho=0
        #inicializa os atributos do grafo
        self.adj = defaultdict(set)
        self.direcionado = direcionado
        self.tamanho = tamanho
        self.adiciona_arestas(arestas)

    #obtem a lista de vertices do grafo
    def get_vertices(self):
        
        return list(self.adj.keys())

    #obtem a lista de arestas do grafo
    def get_arestas(self):
        
        return [(k, v) for k in self.adj.keys() for v in self.adj[k]]

    #Adciona as arestas no grafo
    def adiciona_arestas(self, arestas):
        
        for i, j in zip(arestas["estilo"], arestas["artista favorito"]):
            self.tamanho += 1
            self.adiciona_arco(i, j)

    def adiciona_estilos(self, arestas):
        
        for u, v in arestas:
            self.tamanho += 1
            self.direcionado = True
            self.adiciona_arco(u, v)

    #adciona um arco entre u e v
    def adiciona_arco(self, u, v):
        
        self.adj[u].add(v)
        # Se o grafo é não-direcionado, precisamos adicionar arcos nos dois sentidos.
        if not self.direcionado:
            self.adj[v].add(u)

    #verifica a existencia de arestas
    def existe_aresta(self, u, v):
        return u in self.adj and v in self.adj[u]

    def verifica_tamanho(self):
        return self.tamanho

    def __len__(self):
        return len(self.adj)


    def __str__(self):
        return '{}({})'.format(self.__class__.__name__, dict(self.adj))


    def __getitem__(self, v):
        return self.adj[v]

# %%
grafo = Grafo(df, direcionado=False)

for i in df["estilo"]:
    grafo.adiciona_estilos([('Estilos', str(i))])

print(grafo.get_vertices())
# Out:
# ['Pop', 'Charlie Puth', 'Rock', 'Bon Jovi', 'Eletrônica', 'Martin Garrix', 'Hip Hop', 'J. Cole', 'AC/DC', 'Sertanejo', 'Loubet', 'Lauv', 'Coldplay', 'Matheus & Kauan', 'Niall Horan', 'Pink Floyd', 'Outkast', 'Paula Fernandes', 'Metallica', 'Linkin Park', 'Kendrick Lamar', 'Gian & Giovani', 'Lauryn Hill', 'Zezé di Camargo', 'Daniel', 'Zé Neto & Cristiano', 'R3hab', 'System of a Down', "Guns N' Roses", 'Kanye West', 'Green Day', 'Marshmello', 'David Guetta', 'Big Daddy Kane', 'Major Lazer', 'Axwell', 'MF DOOM', 'Jessie J', 'The Beatles', 'Guilherme & Santiago', 'Henrique & Juliano', 'The Doors', 'A$AP Rocky', 'Jay-Z', 'Oasis', 'Gino & Geno', 'Camila Cabello', 'The Chainsmokers', 'Cristiano Araújo', 'Munhoz & Mariano', 'Estilos']

# %%
def hash_string(palavra):
    a = np.fromstring(palavra, dtype=np.uint8)
    soma = 0
    for i in a:
        soma += i
    return soma

def verifica_dict(visitado:dict, chave:int, nome:str):
    for i in visitado[str(chave)]:
        if i == nome:
            return True
        
    return False

def bfs(G, inicio: str):

    visitado = {}

    fila = []
    ret = []
    fila.append(inicio)

    chave = hash_string(inicio)

    visitado[str(chave)] = []
    visitado[str(chave)].append(inicio)

    count = 0   #usado para acessar estilo


    while fila:
        pr = fila.pop(0)
        ret.append(pr)
        l = list(G["Estilos"])

        for j in list(G[pr]):
            cha = hash_string(j)
            if str(cha) not in visitado:
                visitado[str(cha)] = []
                visitado[str(cha)].append(j)
                fila.append(j)


            elif verifica_dict(visitado=visitado, chave=cha, nome=j) != True:    
                visitado[cha].append(j)
                fila.append(j)

        if fila == []:
            if count<len(l):
                fila.append(l[count])
                count+=1
    return ret

# %%
li = bfs(grafo, inicio="Jay-Z")
print(li)
# Out:
# ['Jay-Z', 'Hip Hop', 'A$AP Rocky', 'Outkast', 'Kendrick Lamar', 'MF DOOM', 'J. Cole', 'Kanye West', 'Lauryn Hill', 'Big Daddy Kane', 'Pop', 'Lauv', 'Jessie J', 'Camila Cabello', 'Niall Horan', 'Charlie Puth', 'Pop', 'Sertanejo', 'Gian & Giovani', 'Daniel', 'Guilherme & Santiago', 'Zezé di Camargo', 'Matheus & Kauan', 'Gino & Geno', 'Cristiano Araújo', 'Munhoz & Mariano', 'Paula Fernandes', 'Loubet', 'Henrique & Juliano', 'Zé Neto & Cristiano', 'Sertanejo', 'Eletrônica', 'The Chainsmokers', 'Marshmello', 'Martin Garrix', 'David Guetta', 'R3hab', 'Major Lazer', 'Axwell', 'Eletrônica', 'Hip Hop', 'Rock', 'Oasis', 'The Beatles', 'AC/DC', "Guns N' Roses", 'Linkin Park', 'System of a Down', 'Coldplay', 'The Doors', 'Metallica', 'Green Day', 'Pink Floyd', 'Bon Jovi', 'Rock']
# <ipython-input-75-f1bf27f37225>:2: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
#   a = np.fromstring(palavra, dtype=np.uint8)
